# %% [markdown]
# <a href="https://colab.research.google.com/github/DaxPatel10/DATA-SCIENSE/blob/main/pandas_for__DS_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# pandas series

# %%
import numpy as np
import pandas as pd

# %%
labels = ['a','b','c']
my_list = [10,20,30]
arr = np.array([10,20,30])
d ={1:10,2:20,3:30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list,index=labels)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(d)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %% [markdown]
# data frame

# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]}
df =pd.DataFrame(data)
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
columns = ['Name', 'Age', 'City', 'Salary']
df2 = pd.DataFrame(data_list, columns = columns)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %% [markdown]
# selection and indextion of columns

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2[["Name","City"]]
# Out:
#     Name      City
# 0   John  New York
# 1   Anna     Paris
# 2  Peter    Berlin
# 3  Linda    London

# %%
df2["Designation"] = ["Doctor","Eng.","Doctor","Eng."]
df2
# Out:
#     Name  Age      City  Salary Designation
# 0   John   28  New York   65000      Doctor
# 1   Anna   34     Paris   70000        Eng.
# 2  Peter   29    Berlin   62000      Doctor
# 3  Linda   42    London   85000        Eng.

# %% [markdown]
# removing

# %%
df2.drop("City",axis = 1,inplace = True)

# %%
df2
# Out:
#     Name  Age  Salary Designation
# 0   John   28   65000      Doctor
# 1   Anna   34   70000        Eng.
# 2  Peter   29   62000      Doctor
# 3  Linda   42   85000        Eng.

# %% [markdown]
# selecting rows

# %%
df2
# Out:
#     Name  Age  Salary Designation
# 0   John   28   65000      Doctor
# 1   Anna   34   70000        Eng.
# 2  Peter   29   62000      Doctor
# 3  Linda   42   85000        Eng.

# %%
df2.loc[0]
# Out:
# Name             John
# Age                28
# Salary          65000
# Designation    Doctor
# Name: 0, dtype: object

# %%
df.iloc[0]
# Out:
# Name          John
# Age             28
# City      New York
# Salary       65000
# Name: 0, dtype: object

# %% [markdown]
# selecting subset of row and columns

# %%
df2
# Out:
#     Name  Age  Salary Designation
# 0   John   28   65000      Doctor
# 1   Anna   34   70000        Eng.
# 2  Peter   29   62000      Doctor
# 3  Linda   42   85000        Eng.

# %%
df.loc[[2,3]][["Name","Age"]]
# Out:
#     Name  Age
# 2  Peter   29
# 3  Linda   42

# %% [markdown]
# conditions

# %%
df2
# Out:
#     Name  Age  Salary Designation
# 0   John   28   65000      Doctor
# 1   Anna   34   70000        Eng.
# 2  Peter   29   62000      Doctor
# 3  Linda   42   85000        Eng.

# %%
df2[df2["Age"]>30]
# Out:
#     Name  Age  Salary Designation
# 1   Anna   34   70000        Eng.
# 3  Linda   42   85000        Eng.

# %%
df2[(df2["Age"]>30)&(df2["Salary"]== 85000)]
# Out:
#     Name  Age  Salary Designation
# 3  Linda   42   85000        Eng.
